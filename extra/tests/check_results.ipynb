# %%
import numpy as np

# %%
data = np.load("cache/yb_lorentzian_compression/sample000_0.4570_1.5000_n02_eta2_spacing0.01.npz")

# %%
print("Array keys:", data.files)

first_array = data['arr_0']
print("\nArray contents:\n", first_array)
